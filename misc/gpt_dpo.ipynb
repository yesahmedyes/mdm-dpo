# %%
# %pip install datasets transformers bitsandbytes peft evaluate
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (2.14.4)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.4)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.15.2)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec>=2021.11.1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.11.1->datasets) (2025.3.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.32.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: torch<3,>=2.2 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from peft) (1.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (1.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (2025.4.26)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.2->bitsandbytes) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.2->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 14.6 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 78.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 63.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 51.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, evaluate, bitsandbytes
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bitsandbytes-0.46.0 evaluate-0.4.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import torch
import pandas as pd

from datasets import Dataset

from transformers import GPT2LMHeadModel, GPT2Tokenizer, BitsAndBytesConfig

from peft import LoraConfig, get_peft_model, TaskType

from torch.optim import AdamW

import torch.nn.functional as F

from torch.optim.lr_scheduler import CosineAnnealingLR, LinearLR, SequentialLR

from tqdm import tqdm

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
quantization_config = BitsAndBytesConfig(
    load_in_8bit=True, llm_int8_threshold=6.0, llm_int8_has_fp16_weight=False
)

base_model = GPT2LMHeadModel.from_pretrained(
    "gpt2", quantization_config=quantization_config
)

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
tokenizer.pad_token = tokenizer.eos_token
tokenizer.truncation_side = "left"
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
lora_config = LoraConfig(
    task_type=TaskType.CAUSAL_LM,
    r=8,
    lora_alpha=32,
    lora_dropout=0.1,
    target_modules=["c_attn"],
    bias="none",
)

base_model = get_peft_model(base_model, lora_config)
base_model.print_trainable_parameters()
# Out:
# trainable params: 294,912 || all params: 124,734,720 || trainable%: 0.2364

# %%
train_dataset_clean = pd.read_csv("./train_dataset_clean.csv").to_dict("records")
eval_dataset_clean = pd.read_csv("./eval_dataset_clean.csv").to_dict("records")
test_dataset_clean = pd.read_csv("./test_dataset_clean.csv").to_dict("records")

print(
    f"Loaded {len(train_dataset_clean)} train samples, {len(eval_dataset_clean)} eval samples, and {len(test_dataset_clean)} test samples"
)
# Out:
# Loaded 142510 train samples, 15835 eval samples, and 8408 test samples

# %%
ref_model = GPT2LMHeadModel.from_pretrained(
    "gpt2", device_map="auto", quantization_config=quantization_config
)

for param in ref_model.parameters():
    param.requires_grad = False

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# base_model.to(device)
# ref_model.to(device)

base_model.train()
ref_model.eval()
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Linear8bitLt(in_features=768, out_features=2304, bias=True)
#           (c_proj): Linear8bitLt(in_features=768, out_features=768, bias=True)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Linear8bitLt(in_features=768, out_features=3072, bias=True)
#           (c_proj): Linear8bitLt(in_features=3072, out_features=768, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
def get_tokenized(input, max_length=256):
    return tokenizer(
        input, return_tensors="pt", padding=True, truncation=True, max_length=max_length
    )


preference_dataset_train = Dataset.from_list(train_dataset_clean[:16000])

prompts_train = get_tokenized([each["prompt"] for each in preference_dataset_train])
choosen_train = get_tokenized([each["chosen"] for each in preference_dataset_train])
rejected_train = get_tokenized([each["rejected"] for each in preference_dataset_train])

preference_dataset_eval = Dataset.from_list(eval_dataset_clean[:1000])

prompts_eval = get_tokenized([each["prompt"] for each in preference_dataset_eval])
choosen_eval = get_tokenized([each["chosen"] for each in preference_dataset_eval])
rejected_eval = get_tokenized([each["rejected"] for each in preference_dataset_eval])

# %%
batch_size = 8
grad_accum_steps = 4

effective_batch_size = batch_size * grad_accum_steps

steps_per_epoch = len(preference_dataset_train) // effective_batch_size

epochs = 2

max_steps = steps_per_epoch * epochs

optimizer = AdamW(base_model.parameters(), lr=1e-5)

warmup_steps = max_steps // 20

warmup_scheduler = LinearLR(
    optimizer,
    start_factor=0.01,
    end_factor=1.0,
    total_iters=warmup_steps,
)

cosine_scheduler = CosineAnnealingLR(
    optimizer,
    T_max=max_steps - warmup_steps,
    eta_min=1e-7,
)

scheduler = SequentialLR(
    optimizer,
    schedulers=[warmup_scheduler, cosine_scheduler],
    milestones=[warmup_steps],
)

# %%
def get_logprobs(
    model,
    prompt_ids,
    completion_ids,
    prompt_mask=None,
    completion_mask=None,
    requires_grad=False,
):
    full_ids = torch.cat([prompt_ids, completion_ids], dim=-1)

    if prompt_mask is not None and completion_mask is not None:
        full_attention_mask = torch.cat([prompt_mask, completion_mask], dim=-1)
    else:
        full_attention_mask = None

    if not requires_grad:
        with torch.no_grad():
            outputs = model(full_ids, attention_mask=full_attention_mask)
    else:
        outputs = model(full_ids, attention_mask=full_attention_mask)

    logits = outputs.logits[:, prompt_ids.shape[1] - 1 : -1, :]

    log_probs = F.log_softmax(logits, dim=-1)

    target_ids = completion_ids

    gathered_log_probs = log_probs.gather(
        dim=-1, index=target_ids.unsqueeze(-1)
    ).squeeze(-1)

    if completion_mask is not None:
        gathered_log_probs = gathered_log_probs * completion_mask

    return gathered_log_probs.sum(dim=-1)

# %%
def dpo_loss(
    policy_model,
    ref_model,
    prompt_ids,
    chosen_ids,
    rejected_ids,
    prompt_mask=None,
    chosen_mask=None,
    rejected_mask=None,
    beta=0.1,
):
    policy_chosen_log_probs = get_logprobs(
        policy_model,
        prompt_ids,
        chosen_ids,
        prompt_mask=prompt_mask,
        completion_mask=chosen_mask,
        requires_grad=True,
    )

    policy_rejected_log_probs = get_logprobs(
        policy_model,
        prompt_ids,
        rejected_ids,
        prompt_mask=prompt_mask,
        completion_mask=rejected_mask,
        requires_grad=True,
    )

    ref_chosen_log_probs = get_logprobs(
        ref_model,
        prompt_ids,
        chosen_ids,
        prompt_mask=prompt_mask,
        completion_mask=chosen_mask,
    )

    ref_rejected_log_probs = get_logprobs(
        ref_model,
        prompt_ids,
        rejected_ids,
        prompt_mask=prompt_mask,
        completion_mask=rejected_mask,
    )

    chosen_rewards = policy_chosen_log_probs - ref_chosen_log_probs
    rejected_rewards = policy_rejected_log_probs - ref_rejected_log_probs

    loss = -F.logsigmoid(beta * (chosen_rewards - rejected_rewards))

    return loss.mean()

# %%
step = 0

for epoch in range(epochs):
    epoch_loss = 0
    num_batches_processed = 0

    for i in range(0, len(preference_dataset_train), batch_size):
        batch_end = min(i + batch_size, len(preference_dataset_train))

        prompts_ids = prompts_train["input_ids"][i:batch_end].to(device)
        chosen_ids = choosen_train["input_ids"][i:batch_end].to(device)
        rejected_ids = rejected_train["input_ids"][i:batch_end].to(device)

        prompts_mask = prompts_train["attention_mask"][i:batch_end].to(device)
        chosen_mask = choosen_train["attention_mask"][i:batch_end].to(device)
        rejected_mask = rejected_train["attention_mask"][i:batch_end].to(device)

        loss = dpo_loss(
            base_model,
            ref_model,
            prompts_ids,
            chosen_ids,
            rejected_ids,
            prompt_mask=prompts_mask,
            chosen_mask=chosen_mask,
            rejected_mask=rejected_mask,
        )

        loss = loss / grad_accum_steps

        loss.backward()

        torch.nn.utils.clip_grad_norm_(base_model.parameters(), max_norm=1.0)

        epoch_loss += loss.item()
        num_batches_processed += 1

        if (num_batches_processed % grad_accum_steps == 0) or (
            batch_end >= len(preference_dataset_train)
        ):
            optimizer.step()
            scheduler.step()
            optimizer.zero_grad()
            step += 1

            print(
                f"Step {step}, Epoch {epoch + 1}, Avg Loss: {epoch_loss / num_batches_processed * grad_accum_steps:.4f}"
            )

            if torch.cuda.is_available():
                torch.cuda.empty_cache()

        del prompts_ids, chosen_ids, rejected_ids
        del prompts_mask, chosen_mask, rejected_mask
        del loss
# Out:
# Step 1, Epoch 1, Avg Loss: 1.0835
# Step 2, Epoch 1, Avg Loss: 1.1006
# Step 3, Epoch 1, Avg Loss: 1.4672
# Step 4, Epoch 1, Avg Loss: 1.9522
# Step 5, Epoch 1, Avg Loss: 1.8988
# Step 6, Epoch 1, Avg Loss: 1.9544
# Step 7, Epoch 1, Avg Loss: 1.8677
# Step 8, Epoch 1, Avg Loss: 1.8076
# Step 9, Epoch 1, Avg Loss: 1.7889
# Step 10, Epoch 1, Avg Loss: 1.7862
# Step 11, Epoch 1, Avg Loss: 1.8245
# Step 12, Epoch 1, Avg Loss: 1.7980
# Step 13, Epoch 1, Avg Loss: 1.7764
# Step 14, Epoch 1, Avg Loss: 1.7389
# Step 15, Epoch 1, Avg Loss: 1.7311
# Step 16, Epoch 1, Avg Loss: 1.7257
# Step 17, Epoch 1, Avg Loss: 1.7990
# Step 18, Epoch 1, Avg Loss: 1.8464
# Step 19, Epoch 1, Avg Loss: 1.8981
# Step 20, Epoch 1, Avg Loss: 1.9023
# Step 21, Epoch 1, Avg Loss: 1.8700
# Step 22, Epoch 1, Avg Loss: 1.9590
# Step 23, Epoch 1, Avg Loss: 2.0069
# Step 24, Epoch 1, Avg Loss: 1.9931
# Step 25, Epoch 1, Avg Loss: 1.9839
# Step 26, Epoch 1, Avg Loss: 2.0041
# Step 27, Epoch 1, Avg Loss: 1.9704
# Step 28, Epoch 1, Avg Loss: 1.9585
# Step 29, Epoch 1, Avg Loss: 1.9427
# Step 30, Epoch 1, Avg Loss: 2.0030
# Step 31, Epoch 1, Avg Loss: 1.9955
# Step 32, Epoch 1, Avg Loss: 1.9866
# Step 33, Epoch 1, Avg Loss: 2.0180
# Step 34, Epoch 1, Avg Loss: 2.0313
# Step 35, Epoch 1, Avg Loss: 2.0361
# Step 36, Epoch 1, Avg Loss: 2.0492
# Step 37, Epoch 1, Avg Loss: 2.0438
# Step 38, Epoch 1, Avg Loss: 2.0499
# Step 39, Epoch 1, Avg Loss: 2.0729
# Step 40, Epoch 1, Avg Loss: 2.0647
# Step 41, Epoch 1, Avg Loss: 2.0576
# Step 42, Epoch 1, Avg Loss: 2.0383
# Step 43, Epoch 1, Avg Loss: 2.0256
# Step 44, Epoch 1, Avg Loss: 2.0183
# Step 45, Epoch 1, Avg Loss: 2.0185
# Step 46, Epoch 1, Avg Loss: 2.0023
# Step 47, Epoch 1, Avg Loss: 1.9965
# Step 48, Epoch 1, Avg Loss: 1.9786
# Step 49, Epoch 1, Avg Loss: 1.9609
# Step 50, Epoch 1, Avg Loss: 1.9618
# Step 51, Epoch 1, Avg Loss: 1.9574
# Step 52, Epoch 1, Avg Loss: 1.9505
# Step 53, Epoch 1, Avg Loss: 1.9363
# Step 54, Epoch 1, Avg Loss: 1.9234
# Step 55, Epoch 1, Avg Loss: 1.9223
# Step 56, Epoch 1, Avg Loss: 1.9101
# Step 57, Epoch 1, Avg Loss: 1.8927
# Step 58, Epoch 1, Avg Loss: 1.8776
# Step 59, Epoch 1, Avg Loss: 1.8949
# Step 60, Epoch 1, Avg Loss: 1.8812
# Step 61, Epoch 1, Avg Loss: 1.8779
# Step 62, Epoch 1, Avg Loss: 1.8812
# Step 63, Epoch 1, Avg Loss: 1.8787
# Step 64, Epoch 1, Avg Loss: 1.8693
# Step 65, Epoch 1, Avg Loss: 1.8576
# Step 66, Epoch 1, Avg Loss: 1.8452
# Step 67, Epoch 1, Avg Loss: 1.8395
# Step 68, Epoch 1, Avg Loss: 1.8327
# Step 69, Epoch 1, Avg Loss: 1.8400
# Step 70, Epoch 1, Avg Loss: 1.8428
# Step 71, Epoch 1, Avg Loss: 1.8361
# Step 72, Epoch 1, Avg Loss: 1.8299
# Step 73, Epoch 1, Avg Loss: 1.8294
# Step 74, Epoch 1, Avg Loss: 1.8255
# Step 75, Epoch 1, Avg Loss: 1.8225
# Step 76, Epoch 1, Avg Loss: 1.8297
# Step 77, Epoch 1, Avg Loss: 1.8353
# Step 78, Epoch 1, Avg Loss: 1.8272
# Step 79, Epoch 1, Avg Loss: 1.8292
# Step 80, Epoch 1, Avg Loss: 1.8275
# Step 81, Epoch 1, Avg Loss: 1.8163
# Step 82, Epoch 1, Avg Loss: 1.8083
# Step 83, Epoch 1, Avg Loss: 1.7971
# Step 84, Epoch 1, Avg Loss: 1.7980
# Step 85, Epoch 1, Avg Loss: 1.7999
# Step 86, Epoch 1, Avg Loss: 1.7879
# Step 87, Epoch 1, Avg Loss: 1.7982
# Step 88, Epoch 1, Avg Loss: 1.8006
# Step 89, Epoch 1, Avg Loss: 1.7976
# Step 90, Epoch 1, Avg Loss: 1.8005
# Step 91, Epoch 1, Avg Loss: 1.7987
# Step 92, Epoch 1, Avg Loss: 1.8008
# Step 93, Epoch 1, Avg Loss: 1.8117
# Step 94, Epoch 1, Avg Loss: 1.8064
# Step 95, Epoch 1, Avg Loss: 1.8045
# Step 96, Epoch 1, Avg Loss: 1.8035
# Step 97, Epoch 1, Avg Loss: 1.8082
# Step 98, Epoch 1, Avg Loss: 1.8025
# Step 99, Epoch 1, Avg Loss: 1.8023
# Step 100, Epoch 1, Avg Loss: 1.8049
# Step 101, Epoch 1, Avg Loss: 1.8121
# Step 102, Epoch 1, Avg Loss: 1.8196
# Step 103, Epoch 1, Avg Loss: 1.8215
# Step 104, Epoch 1, Avg Loss: 1.8201
# Step 105, Epoch 1, Avg Loss: 1.8243
# Step 106, Epoch 1, Avg Loss: 1.8191
# Step 107, Epoch 1, Avg Loss: 1.8120
# Step 108, Epoch 1, Avg Loss: 1.8114
# Step 109, Epoch 1, Avg Loss: 1.8127
# Step 110, Epoch 1, Avg Loss: 1.8121
# Step 111, Epoch 1, Avg Loss: 1.8105
# Step 112, Epoch 1, Avg Loss: 1.8342
# Step 113, Epoch 1, Avg Loss: 1.8287
# Step 114, Epoch 1, Avg Loss: 1.8222
# Step 115, Epoch 1, Avg Loss: 1.8207
# Step 116, Epoch 1, Avg Loss: 1.8263
# Step 117, Epoch 1, Avg Loss: 1.8189
# Step 118, Epoch 1, Avg Loss: 1.8100
# Step 119, Epoch 1, Avg Loss: 1.8140
# Step 120, Epoch 1, Avg Loss: 1.8093
# Step 121, Epoch 1, Avg Loss: 1.8092
# Step 122, Epoch 1, Avg Loss: 1.8080
# Step 123, Epoch 1, Avg Loss: 1.8178
# Step 124, Epoch 1, Avg Loss: 1.8263
# Step 125, Epoch 1, Avg Loss: 1.8441
# Step 126, Epoch 1, Avg Loss: 1.8382
# Step 127, Epoch 1, Avg Loss: 1.8324
# Step 128, Epoch 1, Avg Loss: 1.8286
# Step 129, Epoch 1, Avg Loss: 1.8433
# Step 130, Epoch 1, Avg Loss: 1.8379
# Step 131, Epoch 1, Avg Loss: 1.8360
# Step 132, Epoch 1, Avg Loss: 1.8344
# Step 133, Epoch 1, Avg Loss: 1.8384
# Step 134, Epoch 1, Avg Loss: 1.8374
# Step 135, Epoch 1, Avg Loss: 1.8407
# Step 136, Epoch 1, Avg Loss: 1.8402
# Step 137, Epoch 1, Avg Loss: 1.8389
# Step 138, Epoch 1, Avg Loss: 1.8351
# Step 139, Epoch 1, Avg Loss: 1.8306
# Step 140, Epoch 1, Avg Loss: 1.8251
# Step 141, Epoch 1, Avg Loss: 1.8244
# Step 142, Epoch 1, Avg Loss: 1.8259
# Step 143, Epoch 1, Avg Loss: 1.8228
# Step 144, Epoch 1, Avg Loss: 1.8294
# Step 145, Epoch 1, Avg Loss: 1.8300
# Step 146, Epoch 1, Avg Loss: 1.8253
# Step 147, Epoch 1, Avg Loss: 1.8280
# Step 148, Epoch 1, Avg Loss: 1.8283
# Step 149, Epoch 1, Avg Loss: 1.8270
# Step 150, Epoch 1, Avg Loss: 1.8273
# Step 151, Epoch 1, Avg Loss: 1.8319
# Step 152, Epoch 1, Avg Loss: 1.8251
# Step 153, Epoch 1, Avg Loss: 1.8257
# Step 154, Epoch 1, Avg Loss: 1.8311
# Step 155, Epoch 1, Avg Loss: 1.8372
# Step 156, Epoch 1, Avg Loss: 1.8324
# Step 157, Epoch 1, Avg Loss: 1.8315
# Step 158, Epoch 1, Avg Loss: 1.8256
# Step 159, Epoch 1, Avg Loss: 1.8432
# Step 160, Epoch 1, Avg Loss: 1.8392
# Step 161, Epoch 1, Avg Loss: 1.8386
# Step 162, Epoch 1, Avg Loss: 1.8355
# Step 163, Epoch 1, Avg Loss: 1.8303
# Step 164, Epoch 1, Avg Loss: 1.8359
# Step 165, Epoch 1, Avg Loss: 1.8383
# Step 166, Epoch 1, Avg Loss: 1.8445
# Step 167, Epoch 1, Avg Loss: 1.8438
# Step 168, Epoch 1, Avg Loss: 1.8413
# Step 169, Epoch 1, Avg Loss: 1.8389
# Step 170, Epoch 1, Avg Loss: 1.8365
# Step 171, Epoch 1, Avg Loss: 1.8336
# Step 172, Epoch 1, Avg Loss: 1.8356
# Step 173, Epoch 1, Avg Loss: 1.8340
# Step 174, Epoch 1, Avg Loss: 1.8334
# Step 175, Epoch 1, Avg Loss: 1.8272
# Step 176, Epoch 1, Avg Loss: 1.8244
# Step 177, Epoch 1, Avg Loss: 1.8302
# Step 178, Epoch 1, Avg Loss: 1.8304
# Step 179, Epoch 1, Avg Loss: 1.8291
# Step 180, Epoch 1, Avg Loss: 1.8256
# Step 181, Epoch 1, Avg Loss: 1.8344
# Step 182, Epoch 1, Avg Loss: 1.8327
# Step 183, Epoch 1, Avg Loss: 1.8288
# Step 184, Epoch 1, Avg Loss: 1.8283
# Step 185, Epoch 1, Avg Loss: 1.8301
# Step 186, Epoch 1, Avg Loss: 1.8287
# Step 187, Epoch 1, Avg Loss: 1.8274
# Step 188, Epoch 1, Avg Loss: 1.8314
# Step 189, Epoch 1, Avg Loss: 1.8356
# Step 190, Epoch 1, Avg Loss: 1.8360
# Step 191, Epoch 1, Avg Loss: 1.8368
# Step 192, Epoch 1, Avg Loss: 1.8352
# Step 193, Epoch 1, Avg Loss: 1.8346
# Step 194, Epoch 1, Avg Loss: 1.8339
# Step 195, Epoch 1, Avg Loss: 1.8322
# Step 196, Epoch 1, Avg Loss: 1.8320
# Step 197, Epoch 1, Avg Loss: 1.8282
# Step 198, Epoch 1, Avg Loss: 1.8265
# Step 199, Epoch 1, Avg Loss: 1.8239
# Step 200, Epoch 1, Avg Loss: 1.8262
# Step 201, Epoch 1, Avg Loss: 1.8218
# Step 202, Epoch 1, Avg Loss: 1.8199
# Step 203, Epoch 1, Avg Loss: 1.8179
# Step 204, Epoch 1, Avg Loss: 1.8179
# Step 205, Epoch 1, Avg Loss: 1.8172
# Step 206, Epoch 1, Avg Loss: 1.8148
# Step 207, Epoch 1, Avg Loss: 1.8125
# Step 208, Epoch 1, Avg Loss: 1.8132
# Step 209, Epoch 1, Avg Loss: 1.8156
# Step 210, Epoch 1, Avg Loss: 1.8162
# Step 211, Epoch 1, Avg Loss: 1.8226
# Step 212, Epoch 1, Avg Loss: 1.8205
# Step 213, Epoch 1, Avg Loss: 1.8184
# Step 214, Epoch 1, Avg Loss: 1.8210
# Step 215, Epoch 1, Avg Loss: 1.8196
# Step 216, Epoch 1, Avg Loss: 1.8191
# Step 217, Epoch 1, Avg Loss: 1.8220
# Step 218, Epoch 1, Avg Loss: 1.8198
# Step 219, Epoch 1, Avg Loss: 1.8172
# Step 220, Epoch 1, Avg Loss: 1.8145
# Step 221, Epoch 1, Avg Loss: 1.8148
# Step 222, Epoch 1, Avg Loss: 1.8136
# Step 223, Epoch 1, Avg Loss: 1.8106
# Step 224, Epoch 1, Avg Loss: 1.8088
# Step 225, Epoch 1, Avg Loss: 1.8059
# Step 226, Epoch 1, Avg Loss: 1.8104
# Step 227, Epoch 1, Avg Loss: 1.8100
# Step 228, Epoch 1, Avg Loss: 1.8129
# Step 229, Epoch 1, Avg Loss: 1.8135
# Step 230, Epoch 1, Avg Loss: 1.8109
# Step 231, Epoch 1, Avg Loss: 1.8106
# Step 232, Epoch 1, Avg Loss: 1.8082
# Step 233, Epoch 1, Avg Loss: 1.8046
# Step 234, Epoch 1, Avg Loss: 1.8029
# Step 235, Epoch 1, Avg Loss: 1.8032
# Step 236, Epoch 1, Avg Loss: 1.8001
# Step 237, Epoch 1, Avg Loss: 1.7973
# Step 238, Epoch 1, Avg Loss: 1.7969
# Step 239, Epoch 1, Avg Loss: 1.7987
# Step 240, Epoch 1, Avg Loss: 1.8012
# Step 241, Epoch 1, Avg Loss: 1.8027
# Step 242, Epoch 1, Avg Loss: 1.8026
# Step 243, Epoch 1, Avg Loss: 1.8012
# Step 244, Epoch 1, Avg Loss: 1.8016
# Step 245, Epoch 1, Avg Loss: 1.8027
# Step 246, Epoch 1, Avg Loss: 1.8004
# Step 247, Epoch 1, Avg Loss: 1.8006
# Step 248, Epoch 1, Avg Loss: 1.8007
# Step 249, Epoch 1, Avg Loss: 1.7995
# Step 250, Epoch 1, Avg Loss: 1.7970
# Step 251, Epoch 1, Avg Loss: 1.7978
# Step 252, Epoch 1, Avg Loss: 1.7976
# Step 253, Epoch 1, Avg Loss: 1.7982
# Step 254, Epoch 1, Avg Loss: 1.7956
# Step 255, Epoch 1, Avg Loss: 1.7949
# Step 256, Epoch 1, Avg Loss: 1.7944
# Step 257, Epoch 1, Avg Loss: 1.7933
# Step 258, Epoch 1, Avg Loss: 1.7911
# Step 259, Epoch 1, Avg Loss: 1.7901
# Step 260, Epoch 1, Avg Loss: 1.7900
# Step 261, Epoch 1, Avg Loss: 1.7886
# Step 262, Epoch 1, Avg Loss: 1.7869
# Step 263, Epoch 1, Avg Loss: 1.7870
# Step 264, Epoch 1, Avg Loss: 1.7881
# Step 265, Epoch 1, Avg Loss: 1.7866
# Step 266, Epoch 1, Avg Loss: 1.7848
# Step 267, Epoch 1, Avg Loss: 1.7860
# Step 268, Epoch 1, Avg Loss: 1.7864
# Step 269, Epoch 1, Avg Loss: 1.7849
# Step 270, Epoch 1, Avg Loss: 1.7843
# Step 271, Epoch 1, Avg Loss: 1.7849
# Step 272, Epoch 1, Avg Loss: 1.7890
# Step 273, Epoch 1, Avg Loss: 1.7915
# Step 274, Epoch 1, Avg Loss: 1.7946
# Step 275, Epoch 1, Avg Loss: 1.7941
# Step 276, Epoch 1, Avg Loss: 1.7922
# Step 277, Epoch 1, Avg Loss: 1.7911
# Step 278, Epoch 1, Avg Loss: 1.7951
# Step 279, Epoch 1, Avg Loss: 1.7938
# Step 280, Epoch 1, Avg Loss: 1.7909
# Step 281, Epoch 1, Avg Loss: 1.7930
# Step 282, Epoch 1, Avg Loss: 1.7966
# Step 283, Epoch 1, Avg Loss: 1.7969
# Step 284, Epoch 1, Avg Loss: 1.7947
# Step 285, Epoch 1, Avg Loss: 1.7931
# Step 286, Epoch 1, Avg Loss: 1.7928
# Step 287, Epoch 1, Avg Loss: 1.7940
# Step 288, Epoch 1, Avg Loss: 1.7972
# Step 289, Epoch 1, Avg Loss: 1.7970
# Step 290, Epoch 1, Avg Loss: 1.7999
# Step 291, Epoch 1, Avg Loss: 1.7973
# Step 292, Epoch 1, Avg Loss: 1.7949
# Step 293, Epoch 1, Avg Loss: 1.7931
# Step 294, Epoch 1, Avg Loss: 1.7929
# Step 295, Epoch 1, Avg Loss: 1.7940
# Step 296, Epoch 1, Avg Loss: 1.7900
# Step 297, Epoch 1, Avg Loss: 1.7905
# Step 298, Epoch 1, Avg Loss: 1.7901
# Step 299, Epoch 1, Avg Loss: 1.7905
# Step 300, Epoch 1, Avg Loss: 1.7886
# Step 301, Epoch 1, Avg Loss: 1.7874
# Step 302, Epoch 1, Avg Loss: 1.7866
# Step 303, Epoch 1, Avg Loss: 1.7856
# Step 304, Epoch 1, Avg Loss: 1.7833
# Step 305, Epoch 1, Avg Loss: 1.7814
# Step 306, Epoch 1, Avg Loss: 1.7809
# Step 307, Epoch 1, Avg Loss: 1.7793
# Step 308, Epoch 1, Avg Loss: 1.7773
# Step 309, Epoch 1, Avg Loss: 1.7766
# Step 310, Epoch 1, Avg Loss: 1.7766
# Step 311, Epoch 1, Avg Loss: 1.7762
# Step 312, Epoch 1, Avg Loss: 1.7762
# Step 313, Epoch 1, Avg Loss: 1.7760
# Step 314, Epoch 1, Avg Loss: 1.7762
# Step 315, Epoch 1, Avg Loss: 1.7770
# Step 316, Epoch 1, Avg Loss: 1.7732
# Step 317, Epoch 1, Avg Loss: 1.7724
# Step 318, Epoch 1, Avg Loss: 1.7733
# Step 319, Epoch 1, Avg Loss: 1.7744
# Step 320, Epoch 1, Avg Loss: 1.7733
# Step 321, Epoch 1, Avg Loss: 1.7723
# Step 322, Epoch 1, Avg Loss: 1.7722
# Step 323, Epoch 1, Avg Loss: 1.7722
# Step 324, Epoch 1, Avg Loss: 1.7723
# Step 325, Epoch 1, Avg Loss: 1.7737
# Step 326, Epoch 1, Avg Loss: 1.7737
# Step 327, Epoch 1, Avg Loss: 1.7742
# Step 328, Epoch 1, Avg Loss: 1.7731
# Step 329, Epoch 1, Avg Loss: 1.7717
# Step 330, Epoch 1, Avg Loss: 1.7702
# Step 331, Epoch 1, Avg Loss: 1.7687
# Step 332, Epoch 1, Avg Loss: 1.7660
# Step 333, Epoch 1, Avg Loss: 1.7650
# Step 334, Epoch 1, Avg Loss: 1.7670
# Step 335, Epoch 1, Avg Loss: 1.7648
# Step 336, Epoch 1, Avg Loss: 1.7640
# Step 337, Epoch 1, Avg Loss: 1.7641
# Step 338, Epoch 1, Avg Loss: 1.7640
# Step 339, Epoch 1, Avg Loss: 1.7618
# Step 340, Epoch 1, Avg Loss: 1.7622
# Step 341, Epoch 1, Avg Loss: 1.7625
# Step 342, Epoch 1, Avg Loss: 1.7616
# Step 343, Epoch 1, Avg Loss: 1.7602
# Step 344, Epoch 1, Avg Loss: 1.7598
# Step 345, Epoch 1, Avg Loss: 1.7572
# Step 346, Epoch 1, Avg Loss: 1.7560
# Step 347, Epoch 1, Avg Loss: 1.7559
# Step 348, Epoch 1, Avg Loss: 1.7540
# Step 349, Epoch 1, Avg Loss: 1.7530
# Step 350, Epoch 1, Avg Loss: 1.7533
# Step 351, Epoch 1, Avg Loss: 1.7526
# Step 352, Epoch 1, Avg Loss: 1.7559
# Step 353, Epoch 1, Avg Loss: 1.7529
# Step 354, Epoch 1, Avg Loss: 1.7501
# Step 355, Epoch 1, Avg Loss: 1.7493
# Step 356, Epoch 1, Avg Loss: 1.7473
# Step 357, Epoch 1, Avg Loss: 1.7477
# Step 358, Epoch 1, Avg Loss: 1.7461
# Step 359, Epoch 1, Avg Loss: 1.7449
# Step 360, Epoch 1, Avg Loss: 1.7446
# Step 361, Epoch 1, Avg Loss: 1.7435
# Step 362, Epoch 1, Avg Loss: 1.7441
# Step 363, Epoch 1, Avg Loss: 1.7416
# Step 364, Epoch 1, Avg Loss: 1.7423
# Step 365, Epoch 1, Avg Loss: 1.7407
# Step 366, Epoch 1, Avg Loss: 1.7403
# Step 367, Epoch 1, Avg Loss: 1.7394
# Step 368, Epoch 1, Avg Loss: 1.7439
# Step 369, Epoch 1, Avg Loss: 1.7434
# Step 370, Epoch 1, Avg Loss: 1.7420
# Step 371, Epoch 1, Avg Loss: 1.7421
# Step 372, Epoch 1, Avg Loss: 1.7414
# Step 373, Epoch 1, Avg Loss: 1.7399
# Step 374, Epoch 1, Avg Loss: 1.7375
# Step 375, Epoch 1, Avg Loss: 1.7375
# Step 376, Epoch 1, Avg Loss: 1.7373
# Step 377, Epoch 1, Avg Loss: 1.7359
# Step 378, Epoch 1, Avg Loss: 1.7369
# Step 379, Epoch 1, Avg Loss: 1.7351
# Step 380, Epoch 1, Avg Loss: 1.7338
# Step 381, Epoch 1, Avg Loss: 1.7351
# Step 382, Epoch 1, Avg Loss: 1.7339
# Step 383, Epoch 1, Avg Loss: 1.7343
# Step 384, Epoch 1, Avg Loss: 1.7341
# Step 385, Epoch 1, Avg Loss: 1.7331
# Step 386, Epoch 1, Avg Loss: 1.7315
# Step 387, Epoch 1, Avg Loss: 1.7318
# Step 388, Epoch 1, Avg Loss: 1.7308
# Step 389, Epoch 1, Avg Loss: 1.7321
# Step 390, Epoch 1, Avg Loss: 1.7319
# Step 391, Epoch 1, Avg Loss: 1.7317
# Step 392, Epoch 1, Avg Loss: 1.7306
# Step 393, Epoch 1, Avg Loss: 1.7294
# Step 394, Epoch 1, Avg Loss: 1.7287
# Step 395, Epoch 1, Avg Loss: 1.7280
# Step 396, Epoch 1, Avg Loss: 1.7273
# Step 397, Epoch 1, Avg Loss: 1.7272
# Step 398, Epoch 1, Avg Loss: 1.7284
# Step 399, Epoch 1, Avg Loss: 1.7266
# Step 400, Epoch 1, Avg Loss: 1.7265
# Step 401, Epoch 1, Avg Loss: 1.7278
# Step 402, Epoch 1, Avg Loss: 1.7260
# Step 403, Epoch 1, Avg Loss: 1.7257
# Step 404, Epoch 1, Avg Loss: 1.7246
# Step 405, Epoch 1, Avg Loss: 1.7233
# Step 406, Epoch 1, Avg Loss: 1.7225
# Step 407, Epoch 1, Avg Loss: 1.7242
# Step 408, Epoch 1, Avg Loss: 1.7229
# Step 409, Epoch 1, Avg Loss: 1.7232
# Step 410, Epoch 1, Avg Loss: 1.7234
# Step 411, Epoch 1, Avg Loss: 1.7217
# Step 412, Epoch 1, Avg Loss: 1.7224
# Step 413, Epoch 1, Avg Loss: 1.7214
# Step 414, Epoch 1, Avg Loss: 1.7200
# Step 415, Epoch 1, Avg Loss: 1.7186
# Step 416, Epoch 1, Avg Loss: 1.7188
# Step 417, Epoch 1, Avg Loss: 1.7178
# Step 418, Epoch 1, Avg Loss: 1.7167
# Step 419, Epoch 1, Avg Loss: 1.7148
# Step 420, Epoch 1, Avg Loss: 1.7162
# Step 421, Epoch 1, Avg Loss: 1.7148
# Step 422, Epoch 1, Avg Loss: 1.7131
# Step 423, Epoch 1, Avg Loss: 1.7117
# Step 424, Epoch 1, Avg Loss: 1.7096
# Step 425, Epoch 1, Avg Loss: 1.7092
# Step 426, Epoch 1, Avg Loss: 1.7091
# Step 427, Epoch 1, Avg Loss: 1.7091
# Step 428, Epoch 1, Avg Loss: 1.7080
# Step 429, Epoch 1, Avg Loss: 1.7068
# Step 430, Epoch 1, Avg Loss: 1.7092
# Step 431, Epoch 1, Avg Loss: 1.7088
# Step 432, Epoch 1, Avg Loss: 1.7078
# Step 433, Epoch 1, Avg Loss: 1.7066
# Step 434, Epoch 1, Avg Loss: 1.7072
# Step 435, Epoch 1, Avg Loss: 1.7073
# Step 436, Epoch 1, Avg Loss: 1.7066
# Step 437, Epoch 1, Avg Loss: 1.7068
# Step 438, Epoch 1, Avg Loss: 1.7103
# Step 439, Epoch 1, Avg Loss: 1.7105
# Step 440, Epoch 1, Avg Loss: 1.7120
# Step 441, Epoch 1, Avg Loss: 1.7115
# Step 442, Epoch 1, Avg Loss: 1.7123
# Step 443, Epoch 1, Avg Loss: 1.7111
# Step 444, Epoch 1, Avg Loss: 1.7148
# Step 445, Epoch 1, Avg Loss: 1.7150
# Step 446, Epoch 1, Avg Loss: 1.7142
# Step 447, Epoch 1, Avg Loss: 1.7151
# Step 448, Epoch 1, Avg Loss: 1.7137
# Step 449, Epoch 1, Avg Loss: 1.7136
# Step 450, Epoch 1, Avg Loss: 1.7154
# Step 451, Epoch 1, Avg Loss: 1.7142
# Step 452, Epoch 1, Avg Loss: 1.7145
# Step 453, Epoch 1, Avg Loss: 1.7161
# Step 454, Epoch 1, Avg Loss: 1.7147
# Step 455, Epoch 1, Avg Loss: 1.7142
# Step 456, Epoch 1, Avg Loss: 1.7156
# Step 457, Epoch 1, Avg Loss: 1.7154
# Step 458, Epoch 1, Avg Loss: 1.7158
# Step 459, Epoch 1, Avg Loss: 1.7147
# Step 460, Epoch 1, Avg Loss: 1.7156
# Step 461, Epoch 1, Avg Loss: 1.7151
# Step 462, Epoch 1, Avg Loss: 1.7160
# Step 463, Epoch 1, Avg Loss: 1.7147
# Step 464, Epoch 1, Avg Loss: 1.7154
# Step 465, Epoch 1, Avg Loss: 1.7150
# Step 466, Epoch 1, Avg Loss: 1.7149
# Step 467, Epoch 1, Avg Loss: 1.7153
# Step 468, Epoch 1, Avg Loss: 1.7155
# Step 469, Epoch 1, Avg Loss: 1.7154
# Step 470, Epoch 1, Avg Loss: 1.7166
# Step 471, Epoch 1, Avg Loss: 1.7164
# Step 472, Epoch 1, Avg Loss: 1.7148
# Step 473, Epoch 1, Avg Loss: 1.7165
# Step 474, Epoch 1, Avg Loss: 1.7147
# Step 475, Epoch 1, Avg Loss: 1.7135
# Step 476, Epoch 1, Avg Loss: 1.7125
# Step 477, Epoch 1, Avg Loss: 1.7121
# Step 478, Epoch 1, Avg Loss: 1.7112
# Step 479, Epoch 1, Avg Loss: 1.7110
# Step 480, Epoch 1, Avg Loss: 1.7097
# Step 481, Epoch 1, Avg Loss: 1.7078
# Step 482, Epoch 1, Avg Loss: 1.7074
# Step 483, Epoch 1, Avg Loss: 1.7075
# Step 484, Epoch 1, Avg Loss: 1.7062
# Step 485, Epoch 1, Avg Loss: 1.7081
# Step 486, Epoch 1, Avg Loss: 1.7076
# Step 487, Epoch 1, Avg Loss: 1.7066
# Step 488, Epoch 1, Avg Loss: 1.7087
# Step 489, Epoch 1, Avg Loss: 1.7073
# Step 490, Epoch 1, Avg Loss: 1.7064
# Step 491, Epoch 1, Avg Loss: 1.7080
# Step 492, Epoch 1, Avg Loss: 1.7076
# Step 493, Epoch 1, Avg Loss: 1.7063
# Step 494, Epoch 1, Avg Loss: 1.7062
# Step 495, Epoch 1, Avg Loss: 1.7086
# Step 496, Epoch 1, Avg Loss: 1.7090
# Step 497, Epoch 1, Avg Loss: 1.7093
# Step 498, Epoch 1, Avg Loss: 1.7081
# Step 499, Epoch 1, Avg Loss: 1.7081
# Step 500, Epoch 1, Avg Loss: 1.7088
# Step 501, Epoch 2, Avg Loss: 0.7266
# Step 502, Epoch 2, Avg Loss: 0.9924
# Step 503, Epoch 2, Avg Loss: 1.1645
# Step 504, Epoch 2, Avg Loss: 1.4031
# Step 505, Epoch 2, Avg Loss: 1.4177
# Step 506, Epoch 2, Avg Loss: 1.4415
# Step 507, Epoch 2, Avg Loss: 1.3981
# Step 508, Epoch 2, Avg Loss: 1.4074
# Step 509, Epoch 2, Avg Loss: 1.4103
# Step 510, Epoch 2, Avg Loss: 1.4212
# Step 511, Epoch 2, Avg Loss: 1.4287
# Step 512, Epoch 2, Avg Loss: 1.4222
# Step 513, Epoch 2, Avg Loss: 1.4144
# Step 514, Epoch 2, Avg Loss: 1.4089
# Step 515, Epoch 2, Avg Loss: 1.4043
# Step 516, Epoch 2, Avg Loss: 1.3963
# Step 517, Epoch 2, Avg Loss: 1.4609
# Step 518, Epoch 2, Avg Loss: 1.5017
# Step 519, Epoch 2, Avg Loss: 1.5310
# Step 520, Epoch 2, Avg Loss: 1.5265
# Step 521, Epoch 2, Avg Loss: 1.5133
# Step 522, Epoch 2, Avg Loss: 1.5612
# Step 523, Epoch 2, Avg Loss: 1.6076
# Step 524, Epoch 2, Avg Loss: 1.6037
# Step 525, Epoch 2, Avg Loss: 1.5859
# Step 526, Epoch 2, Avg Loss: 1.6045
# Step 527, Epoch 2, Avg Loss: 1.5787
# Step 528, Epoch 2, Avg Loss: 1.5744
# Step 529, Epoch 2, Avg Loss: 1.5588
# Step 530, Epoch 2, Avg Loss: 1.6089
# Step 531, Epoch 2, Avg Loss: 1.6083
# Step 532, Epoch 2, Avg Loss: 1.6161
# Step 533, Epoch 2, Avg Loss: 1.6346
# Step 534, Epoch 2, Avg Loss: 1.6484
# Step 535, Epoch 2, Avg Loss: 1.6511
# Step 536, Epoch 2, Avg Loss: 1.6558
# Step 537, Epoch 2, Avg Loss: 1.6422
# Step 538, Epoch 2, Avg Loss: 1.6547
# Step 539, Epoch 2, Avg Loss: 1.6668
# Step 540, Epoch 2, Avg Loss: 1.6662
# Step 541, Epoch 2, Avg Loss: 1.6605
# Step 542, Epoch 2, Avg Loss: 1.6441
# Step 543, Epoch 2, Avg Loss: 1.6381
# Step 544, Epoch 2, Avg Loss: 1.6364
# Step 545, Epoch 2, Avg Loss: 1.6358
# Step 546, Epoch 2, Avg Loss: 1.6265
# Step 547, Epoch 2, Avg Loss: 1.6237
# Step 548, Epoch 2, Avg Loss: 1.6091
# Step 549, Epoch 2, Avg Loss: 1.5953
# Step 550, Epoch 2, Avg Loss: 1.5969
# Step 551, Epoch 2, Avg Loss: 1.5931
# Step 552, Epoch 2, Avg Loss: 1.5876
# Step 553, Epoch 2, Avg Loss: 1.5764
# Step 554, Epoch 2, Avg Loss: 1.5682
# Step 555, Epoch 2, Avg Loss: 1.5691
# Step 556, Epoch 2, Avg Loss: 1.5653
# Step 557, Epoch 2, Avg Loss: 1.5574
# Step 558, Epoch 2, Avg Loss: 1.5520
# Step 559, Epoch 2, Avg Loss: 1.5622
# Step 560, Epoch 2, Avg Loss: 1.5515
# Step 561, Epoch 2, Avg Loss: 1.5451
# Step 562, Epoch 2, Avg Loss: 1.5486
# Step 563, Epoch 2, Avg Loss: 1.5474
# Step 564, Epoch 2, Avg Loss: 1.5427
# Step 565, Epoch 2, Avg Loss: 1.5339
# Step 566, Epoch 2, Avg Loss: 1.5247
# Step 567, Epoch 2, Avg Loss: 1.5213
# Step 568, Epoch 2, Avg Loss: 1.5184
# Step 569, Epoch 2, Avg Loss: 1.5225
# Step 570, Epoch 2, Avg Loss: 1.5250
# Step 571, Epoch 2, Avg Loss: 1.5218
# Step 572, Epoch 2, Avg Loss: 1.5165
# Step 573, Epoch 2, Avg Loss: 1.5159
# Step 574, Epoch 2, Avg Loss: 1.5140
# Step 575, Epoch 2, Avg Loss: 1.5153
# Step 576, Epoch 2, Avg Loss: 1.5195
# Step 577, Epoch 2, Avg Loss: 1.5250
# Step 578, Epoch 2, Avg Loss: 1.5170
# Step 579, Epoch 2, Avg Loss: 1.5230
# Step 580, Epoch 2, Avg Loss: 1.5302
# Step 581, Epoch 2, Avg Loss: 1.5215
# Step 582, Epoch 2, Avg Loss: 1.5161
# Step 583, Epoch 2, Avg Loss: 1.5093
# Step 584, Epoch 2, Avg Loss: 1.5088
# Step 585, Epoch 2, Avg Loss: 1.5116
# Step 586, Epoch 2, Avg Loss: 1.5068
# Step 587, Epoch 2, Avg Loss: 1.5145
# Step 588, Epoch 2, Avg Loss: 1.5121
# Step 589, Epoch 2, Avg Loss: 1.5080
# Step 590, Epoch 2, Avg Loss: 1.5083
# Step 591, Epoch 2, Avg Loss: 1.5087
# Step 592, Epoch 2, Avg Loss: 1.5110
# Step 593, Epoch 2, Avg Loss: 1.5199
# Step 594, Epoch 2, Avg Loss: 1.5212
# Step 595, Epoch 2, Avg Loss: 1.5188
# Step 596, Epoch 2, Avg Loss: 1.5164
# Step 597, Epoch 2, Avg Loss: 1.5178
# Step 598, Epoch 2, Avg Loss: 1.5134
# Step 599, Epoch 2, Avg Loss: 1.5167
# Step 600, Epoch 2, Avg Loss: 1.5162
# Step 601, Epoch 2, Avg Loss: 1.5226
# Step 602, Epoch 2, Avg Loss: 1.5321
# Step 603, Epoch 2, Avg Loss: 1.5325
# Step 604, Epoch 2, Avg Loss: 1.5303
# Step 605, Epoch 2, Avg Loss: 1.5342
# Step 606, Epoch 2, Avg Loss: 1.5331
# Step 607, Epoch 2, Avg Loss: 1.5316
# Step 608, Epoch 2, Avg Loss: 1.5318
# Step 609, Epoch 2, Avg Loss: 1.5299
# Step 610, Epoch 2, Avg Loss: 1.5307
# Step 611, Epoch 2, Avg Loss: 1.5336
# Step 612, Epoch 2, Avg Loss: 1.5516
# Step 613, Epoch 2, Avg Loss: 1.5489
# Step 614, Epoch 2, Avg Loss: 1.5446
# Step 615, Epoch 2, Avg Loss: 1.5431
# Step 616, Epoch 2, Avg Loss: 1.5493
# Step 617, Epoch 2, Avg Loss: 1.5449
# Step 618, Epoch 2, Avg Loss: 1.5388
# Step 619, Epoch 2, Avg Loss: 1.5439
# Step 620, Epoch 2, Avg Loss: 1.5410
# Step 621, Epoch 2, Avg Loss: 1.5418
# Step 622, Epoch 2, Avg Loss: 1.5379
# Step 623, Epoch 2, Avg Loss: 1.5470
# Step 624, Epoch 2, Avg Loss: 1.5535
# Step 625, Epoch 2, Avg Loss: 1.5711
# Step 626, Epoch 2, Avg Loss: 1.5669
# Step 627, Epoch 2, Avg Loss: 1.5642
# Step 628, Epoch 2, Avg Loss: 1.5595
# Step 629, Epoch 2, Avg Loss: 1.5708
# Step 630, Epoch 2, Avg Loss: 1.5667
# Step 631, Epoch 2, Avg Loss: 1.5671
# Step 632, Epoch 2, Avg Loss: 1.5669
# Step 633, Epoch 2, Avg Loss: 1.5686
# Step 634, Epoch 2, Avg Loss: 1.5695
# Step 635, Epoch 2, Avg Loss: 1.5743
# Step 636, Epoch 2, Avg Loss: 1.5733
# Step 637, Epoch 2, Avg Loss: 1.5713
# Step 638, Epoch 2, Avg Loss: 1.5701
# Step 639, Epoch 2, Avg Loss: 1.5678
# Step 640, Epoch 2, Avg Loss: 1.5648
# Step 641, Epoch 2, Avg Loss: 1.5654
# Step 642, Epoch 2, Avg Loss: 1.5648
# Step 643, Epoch 2, Avg Loss: 1.5655
# Step 644, Epoch 2, Avg Loss: 1.5664
# Step 645, Epoch 2, Avg Loss: 1.5673
# Step 646, Epoch 2, Avg Loss: 1.5666
# Step 647, Epoch 2, Avg Loss: 1.5690
# Step 648, Epoch 2, Avg Loss: 1.5697
# Step 649, Epoch 2, Avg Loss: 1.5675
# Step 650, Epoch 2, Avg Loss: 1.5690
# Step 651, Epoch 2, Avg Loss: 1.5736
# Step 652, Epoch 2, Avg Loss: 1.5668
# Step 653, Epoch 2, Avg Loss: 1.5672
# Step 654, Epoch 2, Avg Loss: 1.5707
# Step 655, Epoch 2, Avg Loss: 1.5749
# Step 656, Epoch 2, Avg Loss: 1.5706
# Step 657, Epoch 2, Avg Loss: 1.5708
# Step 658, Epoch 2, Avg Loss: 1.5669
# Step 659, Epoch 2, Avg Loss: 1.5860
# Step 660, Epoch 2, Avg Loss: 1.5837
# Step 661, Epoch 2, Avg Loss: 1.5852
# Step 662, Epoch 2, Avg Loss: 1.5832
# Step 663, Epoch 2, Avg Loss: 1.5799
# Step 664, Epoch 2, Avg Loss: 1.5856
# Step 665, Epoch 2, Avg Loss: 1.5878
# Step 666, Epoch 2, Avg Loss: 1.5927
# Step 667, Epoch 2, Avg Loss: 1.5954
# Step 668, Epoch 2, Avg Loss: 1.5912
# Step 669, Epoch 2, Avg Loss: 1.5897
# Step 670, Epoch 2, Avg Loss: 1.5884
# Step 671, Epoch 2, Avg Loss: 1.5863
# Step 672, Epoch 2, Avg Loss: 1.5894
# Step 673, Epoch 2, Avg Loss: 1.5883
# Step 674, Epoch 2, Avg Loss: 1.5896
# Step 675, Epoch 2, Avg Loss: 1.5846
# Step 676, Epoch 2, Avg Loss: 1.5832
# Step 677, Epoch 2, Avg Loss: 1.5875
# Step 678, Epoch 2, Avg Loss: 1.5887
# Step 679, Epoch 2, Avg Loss: 1.5883
# Step 680, Epoch 2, Avg Loss: 1.5864
# Step 681, Epoch 2, Avg Loss: 1.5959
# Step 682, Epoch 2, Avg Loss: 1.5965
# Step 683, Epoch 2, Avg Loss: 1.5949
# Step 684, Epoch 2, Avg Loss: 1.5944
# Step 685, Epoch 2, Avg Loss: 1.5974
# Step 686, Epoch 2, Avg Loss: 1.5953
# Step 687, Epoch 2, Avg Loss: 1.5968
# Step 688, Epoch 2, Avg Loss: 1.6007
# Step 689, Epoch 2, Avg Loss: 1.6034
# Step 690, Epoch 2, Avg Loss: 1.6045
# Step 691, Epoch 2, Avg Loss: 1.6051
# Step 692, Epoch 2, Avg Loss: 1.6046
# Step 693, Epoch 2, Avg Loss: 1.6059
# Step 694, Epoch 2, Avg Loss: 1.6066
# Step 695, Epoch 2, Avg Loss: 1.6036
# Step 696, Epoch 2, Avg Loss: 1.6060
# Step 697, Epoch 2, Avg Loss: 1.6054
# Step 698, Epoch 2, Avg Loss: 1.6045
# Step 699, Epoch 2, Avg Loss: 1.6048
# Step 700, Epoch 2, Avg Loss: 1.6072
# Step 701, Epoch 2, Avg Loss: 1.6070
# Step 702, Epoch 2, Avg Loss: 1.6062
# Step 703, Epoch 2, Avg Loss: 1.6039
# Step 704, Epoch 2, Avg Loss: 1.6038
# Step 705, Epoch 2, Avg Loss: 1.6023
# Step 706, Epoch 2, Avg Loss: 1.5982
# Step 707, Epoch 2, Avg Loss: 1.5974
# Step 708, Epoch 2, Avg Loss: 1.5991
# Step 709, Epoch 2, Avg Loss: 1.6006
# Step 710, Epoch 2, Avg Loss: 1.6028
# Step 711, Epoch 2, Avg Loss: 1.6089
# Step 712, Epoch 2, Avg Loss: 1.6056
# Step 713, Epoch 2, Avg Loss: 1.6028
# Step 714, Epoch 2, Avg Loss: 1.6060
# Step 715, Epoch 2, Avg Loss: 1.6067
# Step 716, Epoch 2, Avg Loss: 1.6067
# Step 717, Epoch 2, Avg Loss: 1.6102
# Step 718, Epoch 2, Avg Loss: 1.6075
# Step 719, Epoch 2, Avg Loss: 1.6062
# Step 720, Epoch 2, Avg Loss: 1.6049
# Step 721, Epoch 2, Avg Loss: 1.6074
# Step 722, Epoch 2, Avg Loss: 1.6078
# Step 723, Epoch 2, Avg Loss: 1.6080
# Step 724, Epoch 2, Avg Loss: 1.6074
# Step 725, Epoch 2, Avg Loss: 1.6056
# Step 726, Epoch 2, Avg Loss: 1.6098
# Step 727, Epoch 2, Avg Loss: 1.6119
# Step 728, Epoch 2, Avg Loss: 1.6131
# Step 729, Epoch 2, Avg Loss: 1.6119
# Step 730, Epoch 2, Avg Loss: 1.6093
# Step 731, Epoch 2, Avg Loss: 1.6082
# Step 732, Epoch 2, Avg Loss: 1.6071
# Step 733, Epoch 2, Avg Loss: 1.6040
# Step 734, Epoch 2, Avg Loss: 1.6032
# Step 735, Epoch 2, Avg Loss: 1.6049
# Step 736, Epoch 2, Avg Loss: 1.6034
# Step 737, Epoch 2, Avg Loss: 1.6014
# Step 738, Epoch 2, Avg Loss: 1.6031
# Step 739, Epoch 2, Avg Loss: 1.6055
# Step 740, Epoch 2, Avg Loss: 1.6065
# Step 741, Epoch 2, Avg Loss: 1.6055
# Step 742, Epoch 2, Avg Loss: 1.6047
# Step 743, Epoch 2, Avg Loss: 1.6057
# Step 744, Epoch 2, Avg Loss: 1.6054
# Step 745, Epoch 2, Avg Loss: 1.6097
# Step 746, Epoch 2, Avg Loss: 1.6077
# Step 747, Epoch 2, Avg Loss: 1.6077
# Step 748, Epoch 2, Avg Loss: 1.6073
# Step 749, Epoch 2, Avg Loss: 1.6070
# Step 750, Epoch 2, Avg Loss: 1.6061
# Step 751, Epoch 2, Avg Loss: 1.6073
# Step 752, Epoch 2, Avg Loss: 1.6072
# Step 753, Epoch 2, Avg Loss: 1.6092
# Step 754, Epoch 2, Avg Loss: 1.6062
# Step 755, Epoch 2, Avg Loss: 1.6065
# Step 756, Epoch 2, Avg Loss: 1.6056
# Step 757, Epoch 2, Avg Loss: 1.6050
# Step 758, Epoch 2, Avg Loss: 1.6039
# Step 759, Epoch 2, Avg Loss: 1.6042
# Step 760, Epoch 2, Avg Loss: 1.6033
# Step 761, Epoch 2, Avg Loss: 1.6019
# Step 762, Epoch 2, Avg Loss: 1.6002
# Step 763, Epoch 2, Avg Loss: 1.6008
# Step 764, Epoch 2, Avg Loss: 1.6032
# Step 765, Epoch 2, Avg Loss: 1.6039
# Step 766, Epoch 2, Avg Loss: 1.6037
# Step 767, Epoch 2, Avg Loss: 1.6072
# Step 768, Epoch 2, Avg Loss: 1.6078
# Step 769, Epoch 2, Avg Loss: 1.6059
# Step 770, Epoch 2, Avg Loss: 1.6064
# Step 771, Epoch 2, Avg Loss: 1.6080
# Step 772, Epoch 2, Avg Loss: 1.6112
# Step 773, Epoch 2, Avg Loss: 1.6119
# Step 774, Epoch 2, Avg Loss: 1.6160
# Step 775, Epoch 2, Avg Loss: 1.6162
# Step 776, Epoch 2, Avg Loss: 1.6168
# Step 777, Epoch 2, Avg Loss: 1.6175
# Step 778, Epoch 2, Avg Loss: 1.6225
# Step 779, Epoch 2, Avg Loss: 1.6226
# Step 780, Epoch 2, Avg Loss: 1.6206
# Step 781, Epoch 2, Avg Loss: 1.6220
# Step 782, Epoch 2, Avg Loss: 1.6250
# Step 783, Epoch 2, Avg Loss: 1.6239
# Step 784, Epoch 2, Avg Loss: 1.6219
# Step 785, Epoch 2, Avg Loss: 1.6200
# Step 786, Epoch 2, Avg Loss: 1.6191
# Step 787, Epoch 2, Avg Loss: 1.6186
# Step 788, Epoch 2, Avg Loss: 1.6224
# Step 789, Epoch 2, Avg Loss: 1.6219
# Step 790, Epoch 2, Avg Loss: 1.6225
# Step 791, Epoch 2, Avg Loss: 1.6206
# Step 792, Epoch 2, Avg Loss: 1.6197
# Step 793, Epoch 2, Avg Loss: 1.6194
# Step 794, Epoch 2, Avg Loss: 1.6213
# Step 795, Epoch 2, Avg Loss: 1.6229
# Step 796, Epoch 2, Avg Loss: 1.6201
# Step 797, Epoch 2, Avg Loss: 1.6215
# Step 798, Epoch 2, Avg Loss: 1.6212
# Step 799, Epoch 2, Avg Loss: 1.6212
# Step 800, Epoch 2, Avg Loss: 1.6198
# Step 801, Epoch 2, Avg Loss: 1.6208
# Step 802, Epoch 2, Avg Loss: 1.6196
# Step 803, Epoch 2, Avg Loss: 1.6187
# Step 804, Epoch 2, Avg Loss: 1.6177
# Step 805, Epoch 2, Avg Loss: 1.6167
# Step 806, Epoch 2, Avg Loss: 1.6156
# Step 807, Epoch 2, Avg Loss: 1.6130
# Step 808, Epoch 2, Avg Loss: 1.6115
# Step 809, Epoch 2, Avg Loss: 1.6124
# Step 810, Epoch 2, Avg Loss: 1.6134
# Step 811, Epoch 2, Avg Loss: 1.6145
# Step 812, Epoch 2, Avg Loss: 1.6146
# Step 813, Epoch 2, Avg Loss: 1.6142
# Step 814, Epoch 2, Avg Loss: 1.6153
# Step 815, Epoch 2, Avg Loss: 1.6159
# Step 816, Epoch 2, Avg Loss: 1.6131
# Step 817, Epoch 2, Avg Loss: 1.6123
# Step 818, Epoch 2, Avg Loss: 1.6119
# Step 819, Epoch 2, Avg Loss: 1.6142
# Step 820, Epoch 2, Avg Loss: 1.6132
# Step 821, Epoch 2, Avg Loss: 1.6119
# Step 822, Epoch 2, Avg Loss: 1.6131
# Step 823, Epoch 2, Avg Loss: 1.6136
# Step 824, Epoch 2, Avg Loss: 1.6142
# Step 825, Epoch 2, Avg Loss: 1.6166
# Step 826, Epoch 2, Avg Loss: 1.6166
# Step 827, Epoch 2, Avg Loss: 1.6179
# Step 828, Epoch 2, Avg Loss: 1.6166
# Step 829, Epoch 2, Avg Loss: 1.6165
# Step 830, Epoch 2, Avg Loss: 1.6158
# Step 831, Epoch 2, Avg Loss: 1.6164
# Step 832, Epoch 2, Avg Loss: 1.6142
# Step 833, Epoch 2, Avg Loss: 1.6140
# Step 834, Epoch 2, Avg Loss: 1.6165
# Step 835, Epoch 2, Avg Loss: 1.6145
# Step 836, Epoch 2, Avg Loss: 1.6140
# Step 837, Epoch 2, Avg Loss: 1.6163
# Step 838, Epoch 2, Avg Loss: 1.6160
# Step 839, Epoch 2, Avg Loss: 1.6149
# Step 840, Epoch 2, Avg Loss: 1.6154
# Step 841, Epoch 2, Avg Loss: 1.6170
# Step 842, Epoch 2, Avg Loss: 1.6175
# Step 843, Epoch 2, Avg Loss: 1.6164
# Step 844, Epoch 2, Avg Loss: 1.6171
# Step 845, Epoch 2, Avg Loss: 1.6149
# Step 846, Epoch 2, Avg Loss: 1.6143
# Step 847, Epoch 2, Avg Loss: 1.6160
# Step 848, Epoch 2, Avg Loss: 1.6153
# Step 849, Epoch 2, Avg Loss: 1.6149
# Step 850, Epoch 2, Avg Loss: 1.6169
# Step 851, Epoch 2, Avg Loss: 1.6167
# Step 852, Epoch 2, Avg Loss: 1.6199
# Step 853, Epoch 2, Avg Loss: 1.6178
# Step 854, Epoch 2, Avg Loss: 1.6155
# Step 855, Epoch 2, Avg Loss: 1.6151
# Step 856, Epoch 2, Avg Loss: 1.6136
# Step 857, Epoch 2, Avg Loss: 1.6153
# Step 858, Epoch 2, Avg Loss: 1.6151
# Step 859, Epoch 2, Avg Loss: 1.6145
# Step 860, Epoch 2, Avg Loss: 1.6156
# Step 861, Epoch 2, Avg Loss: 1.6142
# Step 862, Epoch 2, Avg Loss: 1.6146
# Step 863, Epoch 2, Avg Loss: 1.6129
# Step 864, Epoch 2, Avg Loss: 1.6156
# Step 865, Epoch 2, Avg Loss: 1.6141
# Step 866, Epoch 2, Avg Loss: 1.6150
# Step 867, Epoch 2, Avg Loss: 1.6137
# Step 868, Epoch 2, Avg Loss: 1.6187
# Step 869, Epoch 2, Avg Loss: 1.6191
# Step 870, Epoch 2, Avg Loss: 1.6187
# Step 871, Epoch 2, Avg Loss: 1.6188
# Step 872, Epoch 2, Avg Loss: 1.6184
# Step 873, Epoch 2, Avg Loss: 1.6170
# Step 874, Epoch 2, Avg Loss: 1.6152
# Step 875, Epoch 2, Avg Loss: 1.6166
# Step 876, Epoch 2, Avg Loss: 1.6168
# Step 877, Epoch 2, Avg Loss: 1.6168
# Step 878, Epoch 2, Avg Loss: 1.6182
# Step 879, Epoch 2, Avg Loss: 1.6169
# Step 880, Epoch 2, Avg Loss: 1.6157
# Step 881, Epoch 2, Avg Loss: 1.6175
# Step 882, Epoch 2, Avg Loss: 1.6170
# Step 883, Epoch 2, Avg Loss: 1.6180
# Step 884, Epoch 2, Avg Loss: 1.6193
# Step 885, Epoch 2, Avg Loss: 1.6191
# Step 886, Epoch 2, Avg Loss: 1.6175
# Step 887, Epoch 2, Avg Loss: 1.6183
# Step 888, Epoch 2, Avg Loss: 1.6171
# Step 889, Epoch 2, Avg Loss: 1.6179
# Step 890, Epoch 2, Avg Loss: 1.6182
# Step 891, Epoch 2, Avg Loss: 1.6183
# Step 892, Epoch 2, Avg Loss: 1.6175
# Step 893, Epoch 2, Avg Loss: 1.6168
# Step 894, Epoch 2, Avg Loss: 1.6154
# Step 895, Epoch 2, Avg Loss: 1.6152
# Step 896, Epoch 2, Avg Loss: 1.6152
# Step 897, Epoch 2, Avg Loss: 1.6153
# Step 898, Epoch 2, Avg Loss: 1.6167
# Step 899, Epoch 2, Avg Loss: 1.6157
# Step 900, Epoch 2, Avg Loss: 1.6154
# Step 901, Epoch 2, Avg Loss: 1.6168
# Step 902, Epoch 2, Avg Loss: 1.6152
# Step 903, Epoch 2, Avg Loss: 1.6153
# Step 904, Epoch 2, Avg Loss: 1.6138
# Step 905, Epoch 2, Avg Loss: 1.6134
# Step 906, Epoch 2, Avg Loss: 1.6133
# Step 907, Epoch 2, Avg Loss: 1.6159
# Step 908, Epoch 2, Avg Loss: 1.6152
# Step 909, Epoch 2, Avg Loss: 1.6160
# Step 910, Epoch 2, Avg Loss: 1.6194
# Step 911, Epoch 2, Avg Loss: 1.6191
# Step 912, Epoch 2, Avg Loss: 1.6203
# Step 913, Epoch 2, Avg Loss: 1.6193
# Step 914, Epoch 2, Avg Loss: 1.6186
# Step 915, Epoch 2, Avg Loss: 1.6174
# Step 916, Epoch 2, Avg Loss: 1.6165
# Step 917, Epoch 2, Avg Loss: 1.6153
# Step 918, Epoch 2, Avg Loss: 1.6146
# Step 919, Epoch 2, Avg Loss: 1.6129
# Step 920, Epoch 2, Avg Loss: 1.6133
# Step 921, Epoch 2, Avg Loss: 1.6125
# Step 922, Epoch 2, Avg Loss: 1.6113
# Step 923, Epoch 2, Avg Loss: 1.6106
# Step 924, Epoch 2, Avg Loss: 1.6101
# Step 925, Epoch 2, Avg Loss: 1.6093
# Step 926, Epoch 2, Avg Loss: 1.6105
# Step 927, Epoch 2, Avg Loss: 1.6113
# Step 928, Epoch 2, Avg Loss: 1.6122
# Step 929, Epoch 2, Avg Loss: 1.6117
# Step 930, Epoch 2, Avg Loss: 1.6139
# Step 931, Epoch 2, Avg Loss: 1.6128
# Step 932, Epoch 2, Avg Loss: 1.6123
# Step 933, Epoch 2, Avg Loss: 1.6111
# Step 934, Epoch 2, Avg Loss: 1.6112
# Step 935, Epoch 2, Avg Loss: 1.6123
# Step 936, Epoch 2, Avg Loss: 1.6120
# Step 937, Epoch 2, Avg Loss: 1.6123
# Step 938, Epoch 2, Avg Loss: 1.6156
# Step 939, Epoch 2, Avg Loss: 1.6163
# Step 940, Epoch 2, Avg Loss: 1.6189
# Step 941, Epoch 2, Avg Loss: 1.6190
# Step 942, Epoch 2, Avg Loss: 1.6202
# Step 943, Epoch 2, Avg Loss: 1.6199
# Step 944, Epoch 2, Avg Loss: 1.6240
# Step 945, Epoch 2, Avg Loss: 1.6239
# Step 946, Epoch 2, Avg Loss: 1.6234
# Step 947, Epoch 2, Avg Loss: 1.6261
# Step 948, Epoch 2, Avg Loss: 1.6246
# Step 949, Epoch 2, Avg Loss: 1.6248
# Step 950, Epoch 2, Avg Loss: 1.6278
# Step 951, Epoch 2, Avg Loss: 1.6269
# Step 952, Epoch 2, Avg Loss: 1.6281
# Step 953, Epoch 2, Avg Loss: 1.6302
# Step 954, Epoch 2, Avg Loss: 1.6284
# Step 955, Epoch 2, Avg Loss: 1.6277
# Step 956, Epoch 2, Avg Loss: 1.6307
# Step 957, Epoch 2, Avg Loss: 1.6315
# Step 958, Epoch 2, Avg Loss: 1.6322
# Step 959, Epoch 2, Avg Loss: 1.6319
# Step 960, Epoch 2, Avg Loss: 1.6336
# Step 961, Epoch 2, Avg Loss: 1.6334
# Step 962, Epoch 2, Avg Loss: 1.6341
# Step 963, Epoch 2, Avg Loss: 1.6332
# Step 964, Epoch 2, Avg Loss: 1.6343
# Step 965, Epoch 2, Avg Loss: 1.6339
# Step 966, Epoch 2, Avg Loss: 1.6336
# Step 967, Epoch 2, Avg Loss: 1.6337
# Step 968, Epoch 2, Avg Loss: 1.6336
# Step 969, Epoch 2, Avg Loss: 1.6342
# Step 970, Epoch 2, Avg Loss: 1.6347
# Step 971, Epoch 2, Avg Loss: 1.6347
# Step 972, Epoch 2, Avg Loss: 1.6330
# Step 973, Epoch 2, Avg Loss: 1.6343
# Step 974, Epoch 2, Avg Loss: 1.6325
# Step 975, Epoch 2, Avg Loss: 1.6317
# Step 976, Epoch 2, Avg Loss: 1.6304
# Step 977, Epoch 2, Avg Loss: 1.6301
# Step 978, Epoch 2, Avg Loss: 1.6298
# Step 979, Epoch 2, Avg Loss: 1.6298
# Step 980, Epoch 2, Avg Loss: 1.6295
# Step 981, Epoch 2, Avg Loss: 1.6287
# Step 982, Epoch 2, Avg Loss: 1.6288
# Step 983, Epoch 2, Avg Loss: 1.6296
# Step 984, Epoch 2, Avg Loss: 1.6289
# Step 985, Epoch 2, Avg Loss: 1.6320
# Step 986, Epoch 2, Avg Loss: 1.6323
# Step 987, Epoch 2, Avg Loss: 1.6318
# Step 988, Epoch 2, Avg Loss: 1.6340
# Step 989, Epoch 2, Avg Loss: 1.6336
# Step 990, Epoch 2, Avg Loss: 1.6327
# Step 991, Epoch 2, Avg Loss: 1.6338
# Step 992, Epoch 2, Avg Loss: 1.6339
# Step 993, Epoch 2, Avg Loss: 1.6337
# Step 994, Epoch 2, Avg Loss: 1.6339
# Step 995, Epoch 2, Avg Loss: 1.6375
# Step 996, Epoch 2, Avg Loss: 1.6381
# Step 997, Epoch 2, Avg Loss: 1.6379
# Step 998, Epoch 2, Avg Loss: 1.6368
# Step 999, Epoch 2, Avg Loss: 1.6364
# Step 1000, Epoch 2, Avg Loss: 1.6365

# %%
torch.save(base_model.state_dict(), "best_model.pth")

# %%
import gc

gc.collect()
torch.cuda.empty_cache()

# %%
# base_model.load_state_dict(torch.load("best_model.pth", map_location=device))

# %%
def evaluate_preference_alignment(model):
    model.eval()

    wins, losses, ties = 0, 0, 0

    batch_size = 8

    for i in tqdm(range(0, len(test_dataset_clean[:1024]), batch_size)):
        batch = test_dataset_clean[i : i + batch_size]

        prompts = [sample["prompt"] for sample in batch]
        chosen = [sample["chosen"] for sample in batch]
        rejected = [sample["rejected"] for sample in batch]

        prompt_inputs = get_tokenized(prompts)
        chosen_inputs = get_tokenized(chosen)
        rejected_inputs = get_tokenized(rejected)

        prompt_ids = prompt_inputs["input_ids"].to(device)
        chosen_ids = chosen_inputs["input_ids"].to(device)
        rejected_ids = rejected_inputs["input_ids"].to(device)

        prompt_mask = prompt_inputs["attention_mask"].to(device)
        chosen_mask = chosen_inputs["attention_mask"].to(device)
        rejected_mask = rejected_inputs["attention_mask"].to(device)

        with torch.no_grad():
            chosen_logprobs = get_logprobs(
                model,
                prompt_ids,
                chosen_ids,
                prompt_mask=prompt_mask,
                completion_mask=chosen_mask,
            )

            rejected_logprobs = get_logprobs(
                model,
                prompt_ids,
                rejected_ids,
                prompt_mask=prompt_mask,
                completion_mask=rejected_mask,
            )

        for chosen_lp, rejected_lp in zip(chosen_logprobs, rejected_logprobs):
            if chosen_lp > rejected_lp:
                wins += 1
            elif chosen_lp < rejected_lp:
                losses += 1
            else:
                ties += 1

    total = wins + losses + ties

    print(f"\nResults on HH-RLHF ({total} samples):")
    print(f"Wins     : {wins} ({wins / total:.2%})")
    print(f"Losses   : {losses} ({losses / total:.2%})")
    print(f"Ties     : {ties} ({ties / total:.2%})")

# %%
evaluate_preference_alignment(ref_model)
# Out:
# 100%|██████████| 128/128 [00:28<00:00,  4.51it/s]
# Results on HH-RLHF (1024 samples):
# Wins     : 563 (54.98%)
# Losses   : 461 (45.02%)
# Ties     : 0 (0.00%)

# %%
evaluate_preference_alignment(base_model)
# Out:
# 100%|██████████| 128/128 [00:30<00:00,  4.19it/s]
# Results on HH-RLHF (1024 samples):
# Wins     : 568 (55.47%)
# Losses   : 456 (44.53%)
# Ties     : 0 (0.00%)
